# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = (sum((y-yp)**2))/len(y)
    return mse

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 221.034
# The Mean absolute error is 11.699

# %% [markdown]
# ## Homework 1
# # Heart Disease UCI
#  它可以用來預測心臟病的高危險群，並加以避免
# # 創作者：
# 1。匈牙利心髒病學會。布達佩斯：Andras Janosi，MD
# 2.瑞士蘇黎世大學醫院：William Steinbrunn，醫學博士
# 3.瑞士巴塞爾大學醫院：Matthias Pfisterer，醫學博士
# 4. VA醫療中心，長灘和克利夫蘭診所基金會：Robert Detrano，醫學博士，博士
# 捐助者：David W. Aha（aha'@'ics.uci.edu）（714）856-8779
# ## 資料從何而來
# 他是以收集實際病例來獲取資料
# ## 蒐集而來的資料型態為何
# 他是CSV表格
# ## 這組資料想解決的問題
# 這組資料主要是想要判斷人是不是心臟病的高風險族群，這樣就能在心臟病爆發前有效阻止，而這個人是否為高風險族群，可以用正確率解決。

# %% [markdown]
# ## Homework 2
# ## 1
# 判斷核心客群，載客量多的位置
# ## 2
# 可以從載客司機，google地圖，甚至是客戶問卷
# ## 3
# 可以是表格，或是含有載客位置的地圖
# ## 4
# 我們主要希望判斷是否目標客群，所以正確率可以驗證這個問題
# 若要判斷主要載客位置，MSE可以驗證次問題
