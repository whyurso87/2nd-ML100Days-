# %%
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# 此函數會幫我們把多張影像畫成一張多宮格圖
def img_combine(img, ncols=8, size=1, path=False):
    from math import ceil
    import matplotlib.pyplot as plt
    import numpy as np
    nimg = len(img)
    nrows = int(ceil(nimg/ncols))
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, sharex=True, sharey=True, figsize=(ncols*size,nrows*size))
    if nrows == 0:
        return
    elif ncols == 1:
        for r, ax in zip(np.arange(nrows), axes):
            nth=r
            if nth < nimg:
                ax.imshow(img[nth], cmap='rainbow', vmin=0, vmax=1)
                
            ax.set_axis_off()
    elif nrows == 1:
        for c, ax in zip(np.arange(ncols), axes):
            nth=c
            if nth < nimg:
                ax.imshow(img[nth], cmap='rainbow', vmin=0, vmax=1)
            ax.set_axis_off()
    else:
        for r, row in zip(np.arange(nrows), axes):
            for c, ax in zip(np.arange(ncols), row):
                nth=r*ncols+c
                if nth < nimg:
                    ax.imshow(img[nth], cmap='rainbow', vmin=0, vmax=1)
                ax.set_axis_off()
    plt.show()

# %%
# 讀取 Cifar-10 資料集
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
# 取前 32 張圖片做視覺化
images = x_train[:32]
img_combine(images)

# %%
# 建立 ImageDataGenerator，並指定我們要做資料增強的數值範圍
data_generator = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)

# %%
# 注意！！ ImageDataGenerator 是一個 Generator (生成器)! 對 Generator 不熟悉的同學請回到 Day098 做複習。
# 使用 .flow 後，就會對我們的影像進行增強，再 call next 取出 generator 的圖像。(shuffle=False 因為我們希望圖像的順序不要改變，方便觀察。實際訓練時預設是 shuffle=True) 
augmented_iamges = next(data_generator.flow(images, shuffle=False))
img_combine(augmented_iamges.astype("int")) # 注意在訓練時神經網路時，圖像資料必須要是 float32，但在做視覺化時要轉為 int 才能順利畫圖。所以為了畫圖才把資料轉為 int

# %%
# 因為隨機性的關係，所以一樣的圖像再經過一次 generator 後的結果不一定相同
augmented_iamges = next(data_generator.flow(images, shuffle=False))
img_combine(augmented_iamges.astype("int"))

# %% [markdown]
# ## 作業

# %% [markdown]
# 請使用 ImageDataGenerator 來進行 Cifar-10 資料集的訓練，並觀察不同的圖像增強方法是否會顯著影響訓練結果

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.optimizers import RMSprop, Adam
import keras
batch_size = 128 # batch 的大小，如果出現 OOM error，請降低這個值
num_classes = 10 # 類別的數量，Cifar 10 共有 10 個類別
epochs = 10 # 訓練的 epochs 數量

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_19 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_20 (Activation)   (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_21 (Activation)   (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_22 (Activation)   (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               1180160
# _________________________________________________________________
# activation_23 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_24 (Activation)   (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

datagen = ImageDataGenerator()
datagen.fit(x_train)

model.fit_generator(datagen.flow(x_train, y_train,
                        batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        steps_per_epoch=10,
                        workers=4)


history =model.fit_generator(datagen.flow(x_train, y_train,
                        batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        steps_per_epoch=10,
                        workers=4)

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/10
# 10/10 [==============================] - 3s 306ms/step - loss: 2.3055 - acc: 0.1172 - val_loss: 2.2107 - val_acc: 0.1837
# Epoch 2/10
# 10/10 [==============================] - 1s 68ms/step - loss: 2.3335 - acc: 0.1359 - val_loss: 2.1742 - val_acc: 0.2050
# Epoch 3/10
# 10/10 [==============================] - 1s 69ms/step - loss: 2.1469 - acc: 0.1930 - val_loss: 2.1163 - val_acc: 0.2672
# Epoch 4/10
# 10/10 [==============================] - 1s 68ms/step - loss: 2.1009 - acc: 0.2313 - val_loss: 2.1355 - val_acc: 0.2166
# Epoch 5/10
# 10/10 [==============================] - 1s 68ms/step - loss: 2.0218 - acc: 0.2477 - val_loss: 2.0139 - val_acc: 0.2562
# Epoch 6/10
# 10/10 [==============================] - 1s 68ms/step - loss: 2.0497 - acc: 0.2602 - val_loss: 2.0069 - val_acc: 0.2616
# Epoch 7/10
# 10/10 [==============================] - 1s 68ms/step - loss: 1.9311 - acc: 0.2922 - val_loss: 1.9487 - val_acc: 0.2724
# Epoch 8/10
# 10/10 [==============================] - 1s 69ms/step - loss: 1.9309 - acc: 0.2914 - val_loss: 2.0785 - val_acc: 0.2506
# Epoch 9/10
# 10/10 [==============================] - 1s 69ms/step - loss: 1.9365 - acc: 0.2922 - val_loss: 1.8104 - val_acc: 0.3561
# Epoch 10/10
# 10/10 [==============================] - 1s 68ms/step - loss: 1.8638 - acc: 0.3227 - val_loss: 1.8642 - val_acc: 0.3286
# Epoch 1/10
# 10/10 [==============================] - 1s 71ms/step - loss: 1.9346 - acc: 0.3070 - val_loss: 1.8011 - val_acc: 0.3434
# Epoch 2/10
# 10/10 [==============================] - 1s 69ms/step - loss: 1.7984 - acc: 0.3703 - val_loss: 1.7066 - val_acc: 0.3860
# Epoch 3/10
# 10/10 [==============================] - 1s 69ms/step - loss: 1.7494 - acc: 0.3680 - val_loss: 1.9624 - val_acc: 0.2974
# Epoch 4/10
# 10/10 [==============================] - 1s 68ms/step - loss: 1.8053 - acc: 0.3367 - val_loss: 1.8292 - val_acc: 0.3478
# Epoch 5/10
# 10/10 [==============================] - 1s 67ms/step - loss: 1.7878 - acc: 0.3461 - val_loss: 1.6477 - val_acc: 0.4135
# Epoch 6/10
# 10/10 [==============================] - 1s 69ms/step - loss: 1.8213 - acc: 0.3563 - val_loss: 1.6275 - val_acc: 0.4245
# Epoch 7/10
# 10/10 [==============================] - 1s 67ms/step - loss: 1.7369 - acc: 0.3758 - val_loss: 1.7145 - val_acc: 0.3887
# Epoch 8/10
# 10/10 [==============================] - 1s 67ms/step - loss: 1.7143 - acc: 0.3727 - val_loss: 1.5569 - val_acc: 0.4425
# Epoch 9/10
# 10/10 [==============================] - 1s 68ms/step - loss: 1.7386 - acc: 0.3797 - val_loss: 1.6656 - val_acc: 0.4082
# Epoch 10/10
# 10/10 [==============================] - 1s 67ms/step - loss: 1.7123 - acc: 0.3758 - val_loss: 1.7899 - val_acc: 0.3501
# Test loss: 1.7898904747009277
# Test accuracy: 0.3501

# %%
data_generatortest = ImageDataGenerator(
    rotation_range=50,
    width_shift_range=0.4,
    height_shift_range=0.4,
    horizontal_flip=True)

# %%
data_generatortest.fit(x_train)
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

model.fit_generator(data_generatortest.flow(x_train, y_train,
                        batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        steps_per_epoch=10,
                        workers=4)


history = model.fit_generator(data_generatortest.flow(x_train, y_train,
                        batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        steps_per_epoch=10,
                        workers=4)

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/10
# 10/10 [==============================] - 1s 139ms/step - loss: 2.3232 - acc: 0.2172 - val_loss: 1.8854 - val_acc: 0.3041
# Epoch 2/10
# 10/10 [==============================] - 1s 69ms/step - loss: 1.9983 - acc: 0.2477 - val_loss: 1.9890 - val_acc: 0.2766
# Epoch 3/10
# 10/10 [==============================] - 1s 68ms/step - loss: 2.0151 - acc: 0.2320 - val_loss: 1.9253 - val_acc: 0.2977
# Epoch 4/10
# 10/10 [==============================] - 1s 67ms/step - loss: 2.0254 - acc: 0.2367 - val_loss: 1.8748 - val_acc: 0.3117
# Epoch 5/10
# 10/10 [==============================] - 1s 67ms/step - loss: 1.9714 - acc: 0.2758 - val_loss: 1.8728 - val_acc: 0.3033
# Epoch 6/10
# 10/10 [==============================] - 1s 68ms/step - loss: 2.0057 - acc: 0.2469 - val_loss: 1.8157 - val_acc: 0.3285
# Epoch 7/10
# 10/10 [==============================] - 1s 69ms/step - loss: 2.0206 - acc: 0.2625 - val_loss: 1.8148 - val_acc: 0.3267
# Epoch 8/10
# 10/10 [==============================] - 1s 69ms/step - loss: 2.0123 - acc: 0.2437 - val_loss: 1.8342 - val_acc: 0.3235
# Epoch 9/10
# 10/10 [==============================] - 1s 69ms/step - loss: 2.0114 - acc: 0.2406 - val_loss: 1.7945 - val_acc: 0.3857
# Epoch 10/10
# 10/10 [==============================] - 1s 70ms/step - loss: 2.0121 - acc: 0.2656 - val_loss: 1.8448 - val_acc: 0.3276
# Epoch 1/10
# 10/10 [==============================] - 1s 98ms/step - loss: 1.9866 - acc: 0.2773 - val_loss: 1.8325 - val_acc: 0.3260
# Epoch 2/10
# 10/10 [==============================] - 1s 68ms/step - loss: 1.9720 - acc: 0.2672 - val_loss: 2.1988 - val_acc: 0.2320
# Epoch 3/10
# 10/10 [==============================] - 1s 68ms/step - loss: 2.0067 - acc: 0.2625 - val_loss: 1.7438 - val_acc: 0.3828
# Epoch 4/10
# 10/10 [==============================] - 1s 68ms/step - loss: 1.9509 - acc: 0.2836 - val_loss: 1.7080 - val_acc: 0.3824
# Epoch 5/10
# 10/10 [==============================] - 1s 69ms/step - loss: 1.9448 - acc: 0.2695 - val_loss: 1.7885 - val_acc: 0.3663
# Epoch 6/10
# 10/10 [==============================] - 1s 69ms/step - loss: 1.9683 - acc: 0.2602 - val_loss: 1.7504 - val_acc: 0.3747
# Epoch 7/10
# 10/10 [==============================] - 1s 68ms/step - loss: 1.9295 - acc: 0.3016 - val_loss: 1.8316 - val_acc: 0.3456
# Epoch 8/10
# 10/10 [==============================] - 1s 68ms/step - loss: 1.9291 - acc: 0.3016 - val_loss: 1.6998 - val_acc: 0.3814
# Epoch 9/10
# 10/10 [==============================] - 1s 68ms/step - loss: 1.9269 - acc: 0.2844 - val_loss: 1.9722 - val_acc: 0.2899
# Epoch 10/10
# 10/10 [==============================] - 1s 67ms/step - loss: 1.9918 - acc: 0.2727 - val_loss: 1.8067 - val_acc: 0.3423
# Test loss: 1.8067087619781494
# Test accuracy: 0.3423
